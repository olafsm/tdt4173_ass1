# %% [markdown]
# # Decision Tree
#
#
# For this problem, you will be implementing a Decision Tree classifier that works on discrete (categorical) features. Although a relatively simple learning algorithm, the Decision Tree is often used as a fundamental building block for more powerful (and popular) models such as Random Forest and Gradient Boosted ensembles.
#
# You should base your solution on the [ID3](https://en.wikipedia.org/wiki/ID3_algorithmhttps://en.wikipedia.org/wiki/ID3_algorithm) algorithm. This is a basic tree-learning algorithm that greedly grows a tree based on _information gain_ (reduction in entropy). Please refer to Chapter 3 of _Machine Learning_ by Tom M. Mitchell for more details.
#
#
# We have provided some skeleton code for the classifier, along with a couple of utility functions in the [decision_tree.py](./decision_tree.py) module. Please fill out the functions marked with `TODO` and feel free to add extra constructor arguments as you see fit (just make sure the default constructor solves the first dataset).

# %%
# %load_ext autoreload

# %% [markdown]
# We begin by loading necessary packages. Below follows a short description of the imported modules:
#
# - `numpy` is the defacto python package for numerical calculation. Most other numerical libraries (including pandas) is based on numpy.
# - `pandas` is a widely used package for manipulating (mostly) tabular data
# - `decision_tree` refers to the module in this folder that should be further implemented by you
#
# Note: The `%autoreload` statement is an [IPython magic command](https://ipython.readthedocs.io/en/stable/interactive/magics.html) that automatically reloads the newest version of all imported modules within the cell. This means that you can edit the `decision_tree.py` file and just rerun this cell to get the updated version.

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ## [1] First Dataset
#
# The first dataset is a toy problem lifted from Table 3.2 in the Machine Learning textbook. The objective is to predict whether a given day is suitable for playing tennis based on several weather conditions.
#
# ### [1.1] Load Data
#
# We begin by loading data from the .csv file located in the same folder as this notebook.

# %%
data_1 = pd.read_csv('data_1.csv')
data_1
# Out:
#      Outlook Temperature Humidity    Wind Play Tennis
# 0      Sunny         Hot     High    Weak          No
# 1      Sunny         Hot     High  Strong          No
# 2   Overcast         Hot     High    Weak         Yes
# 3       Rain        Mild     High    Weak         Yes
# 4       Rain        Cool   Normal    Weak         Yes
# 5       Rain        Cool   Normal  Strong          No
# 6   Overcast        Cool   Normal  Strong         Yes
# 7      Sunny        Mild     High    Weak          No
# 8      Sunny        Cool   Normal    Weak         Yes
# 9       Rain        Mild   Normal    Weak         Yes
# 10     Sunny        Mild   Normal  Strong         Yes
# 11  Overcast        Mild     High  Strong         Yes
# 12  Overcast         Hot   Normal    Weak         Yes
# 13      Rain        Mild     High  Strong          No

# %% [markdown]
# ### [1.2] Fit and Evaluate Model
#
# Next we fit and evaluate a Decision Tree over the dataset. We first partition the data into the dependent (`y` = Play Tennis) and independent (`X` = everything else) variables. We then initialize a Decision Tree learner and fit it to all the data. Finally, we evaluate the model over the same data by calculating its accuracy, i.e. the fraction of correctly classified samples.
#
# Note that `.fit` and `.predict` will crash until you implement these two methods in [decision_tree.py](./decision_tree.py).
#
# Assuming that you've correctly implemented the ID3 algorithm as described in the course textbook, you should expect the model to perfectly fit the training data.
#
# **Accepted Performance:** Accuracy = 100%

# %%
# %autoreload
import decision_tree as dt  # <-- Your implementation
# Separate independent (X) and dependent (y) variables
X = data_1.drop(columns=['Play Tennis'])
y = data_1['Play Tennis']

# Create and fit a Decrision Tree classifier
model_1 = dt.DecisionTree()  # <-- Should work with default constructor
model_1.fit(X, y)

# Verify that it perfectly fits the training set
#print(f'Accuracy: {dt.accuracy(y_true=y, y_pred=model_1.predict(X)) * 100 :.1f}%')
# Out:
# ___________________Node 1 created__________________
# Outlook information gain: 0.9403
# Temperature information gain: 0.9403
# Humidity information gain: 0.9403
# Wind information gain: 0.9403
# ['Outlook' 'Temperature' 'Humidity' 'Wind']
# {'Sunny': [0, 1, 7, 8, 10], 'Rain': [3, 4, 5, 9, 13], 'Overcast': [2, 6, 11, 12]}
#    Temperature Humidity    Wind
# 0          Hot     High    Weak
# 1          Hot     High  Strong
# 2          Hot     High    Weak
# 3         Mild     High    Weak
# 4         Cool   Normal    Weak
# 5         Cool   Normal  Strong
# 6         Cool   Normal  Strong
# 7         Mild     High    Weak
# 8         Cool   Normal    Weak
# 9         Mild   Normal    Weak
# 10        Mild   Normal  Strong
# 11        Mild     High  Strong
# 12         Hot   Normal    Weak
# 13        Mild     High  Strong
#
# ___________________Node 2 created__________________
# Temperature information gain: 0.9710
# Humidity information gain: 0.9710
# Wind information gain: 0.9710
# ['Temperature' 'Humidity' 'Wind']
# {'Mild': [2, 4], 'Hot': [0, 1], 'Cool': [3]}
#   Humidity    Wind
# 0     High    Weak
# 1     High  Strong
# 2     High    Weak
# 3   Normal    Weak
# 4   Normal  Strong
#
# ___________________Node 3 created__________________
# Humidity information gain: 1.0000
# Wind information gain: 1.0000
# ['Humidity' 'Wind']
# {'Normal': [1], 'High': [0]}
#      Wind
# 0    Weak
# 1  Strong
#
# ___________________Node 4 created__________________
# Wind information gain: 0.0000
# ['Wind']
#
# Leaf node value: Yes
#
# ___________________Node 5 created__________________
# Wind information gain: 0.0000
# ['Wind']
#
# Leaf node value: No
#
# ___________________Node 6 created__________________
# Humidity information gain: 0.0000
# Wind information gain: 0.0000
# ['Humidity' 'Wind']
#
# Leaf node value: No
#
# ___________________Node 7 created__________________
# Humidity information gain: 0.0000
# Wind information gain: 0.0000
# ['Humidity' 'Wind']
#
# Leaf node value: Yes
#
# ___________________Node 8 created__________________
# Temperature information gain: 0.9710
# Humidity information gain: 0.9710
# Wind information gain: 0.9710
# ['Temperature' 'Humidity' 'Wind']
# {'Mild': [0, 3, 4], 'Cool': [1, 2]}
#   Humidity    Wind
# 0     High    Weak
# 1   Normal    Weak
# 2   Normal  Strong
# 3   Normal    Weak
# 4     High  Strong
#
# ___________________Node 9 created__________________
# Humidity information gain: 0.9183
# Wind information gain: 0.9183
# ['Humidity' 'Wind']
# {'High': [0, 2], 'Normal': [1]}
#      Wind
# 0    Weak
# 1    Weak
# 2  Strong
#
# ___________________Node 10 created__________________
# Wind information gain: 1.0000
# ['Wind']
# {'Strong': [1], 'Weak': [0]}
# Empty DataFrame
# Columns: []
# Index: [0, 1]
#
# ___________________Node 11 created__________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-33dcaf1bef5c> in <module>
#       7 # Create and fit a Decrision Tree classifier
#       8 model_1 = dt.DecisionTree()  # <-- Should work with default constructor
# ----> 9 model_1.fit(X, y)
#      10
#      11 # Verify that it perfectly fits the training set
#
# ~\PycharmProjects\tdt4173_ass1\decision_tree\decision_tree.py in fit(self, X, y)
#     104             nc_y.reset_index(drop=True, inplace=True)
#     105
# --> 106             nn = self.fit(nc_x, nc_y)
#     107             n.children.append(nn)
#     108         return n
#
# ~\PycharmProjects\tdt4173_ass1\decision_tree\decision_tree.py in fit(self, X, y)
#     104             nc_y.reset_index(drop=True, inplace=True)
#     105
# --> 106             nn = self.fit(nc_x, nc_y)
#     107             n.children.append(nn)
#     108         return n
#
# ~\PycharmProjects\tdt4173_ass1\decision_tree\decision_tree.py in fit(self, X, y)
#     104             nc_y.reset_index(drop=True, inplace=True)
#     105
# --> 106             nn = self.fit(nc_x, nc_y)
#     107             n.children.append(nn)
#     108         return n
#
# ~\PycharmProjects\tdt4173_ass1\decision_tree\decision_tree.py in fit(self, X, y)
#     104             nc_y.reset_index(drop=True, inplace=True)
#     105
# --> 106             nn = self.fit(nc_x, nc_y)
#     107             n.children.append(nn)
#     108         return n
#
# ~\PycharmProjects\tdt4173_ass1\decision_tree\decision_tree.py in fit(self, X, y)
#      69         IG = np.array(information_gain(X, y))
#      70         indices = X.columns.values
# ---> 71         largest = indices[IG.argmax()]
#      72         #print(IG)
#      73         print(indices)
#
# ValueError: attempt to get argmax of an empty sequence

# %% [markdown]
# ### [1.3] Inspect Classification Rules
#
# A big advantage of Decision Trees is that they are relatively transparent learners. By this we mean that it is easy for an outside observer to analyse and understand how the model makes its decisions. The problem of being able to reason about how a machine learning model reasons is known as _Explainable AI_ and is often a desirable property of machine learning systems.
#
# Every time a Decision Tree is evaluated, the datapoint is compared against a set of nodes starting at the root of the tree and (typically) ending at one of the leaf nodes. An equivalent way to view this reasoning is as an implication rule ($A \rightarrow B$) where the antecedent ($A$) is a conjunction of of attribute values and the consequent ($B$) is the predicted label. For instance, if a path down the tree first checks if Outlook=Rain, then checks if Wind=Strong, and then predicts Play Tennis=No, this line of reasoning can be represented as:
#
# - If $Outlook=Rain \cap Wind=Strong \rightarrow$ then predict $Play Tennis = No$
#
# We will leverage this property to export the decision tree you just created as a set of rules. For the subsequent cell to work, you must also have implemented the `.get_rules()` method in the provided boilerplate code.

# %%
for rules, label in model_1.get_rules():
    conjunction = ' ∩ '.join(f'{attr}={value}' for attr, value in rules)
    print(f'{"✅" if label == "Yes" else "❌"} {conjunction} => {label}')
# Out:
# Outlook
# None
# Temperature
# None
# Humidity
# None
# Wind
# Yes
# Wind
# No
# Humidity
# No
# Humidity
# Yes

# %% [markdown]
# ## [2] Second Dataset
#
# The second dataset involves predicting whether an investment opportunity will result in a successful `Outcome` or not. To make this prediction, you are given a dataset of 200 historical$^1$ business ventures and their outcome, along with the following observed features:
#
# - Whether the business oportunity is in a lucurative market or not
# - Whether the presented business idea has a competitive advantage
# - Whether the second opinion from another investor is positive or not
# - The founder's previous experience with startups
# - The founder's favorite color
# - The founder's [Zodiac Sign](https://en.wikipedia.org/wiki/Astrology)
#
# ---
# [1] Disclaimer: The dataset is not based on real-world business ventures. It is synthetic and generated by us. Also, it should not be considered financial advice.
#
# ### [2.1] Load Data
#
# This dataset can also be found in a .csv file in the same folder as this notebook.

# %%
data_2 = pd.read_csv('data_2.csv')
data_2
# Out:
#     Founder Zodiac Founder Experience Second Opinion Competitive Advantage  \
# 0           cancer           moderate       negative                   yes
# 1           cancer               high       positive                   yes
# 2          scorpio                low       negative                    no
# 3           cancer                low       negative                    no
# 4         aquarius                low       positive                   yes
# ..             ...                ...            ...                   ...
# 195      capricorn           moderate       positive                    no
# 196       aquarius                low       negative                    no
# 197         cancer           moderate       negative                    no
# 198          virgo           moderate       negative                    no
# 199      capricorn           moderate       negative                   yes
#
#     Founder Favourite Color Lucurative Market  Outcome  Split
# 0                     green               yes  success  train
# 1                      blue                no  failure  train
# 2                     green                no  failure  train
# 3                     black               yes  failure  train
# 4                       red               yes  success  train
# ..                      ...               ...      ...    ...
# 195                     red               yes  failure   test
# 196                  yellow                no  failure   test
# 197                  yellow               yes  success   test
# 198                   black               yes  failure   test
# 199                   white               yes  failure   test
#
# [200 rows x 8 columns]

# %% [markdown]
# ### [2.2] Split Data
#
# We've also taken the liberty to pre-split the dataset into three different sets:
#
# - `train` contains 50 samples that you should use to generate the tree
# - `valid` contains 50 samples that you can use to evaluate different preprocessing methods and variations to the tree-learning algorithm.
# - `test` contains 100 samples and should only be used to evaluate the final model once you're done experimenting.

# %%
# %autoreload
import decision_tree as dt  # <-- Your implementation

data_2_train = data_2.query('Split == "train"')
data_2_valid = data_2.query('Split == "valid"')
data_2_test = data_2.query('Split == "test"')
X_train, y_train = data_2_train.drop(columns=['Outcome', 'Split']), data_2_train.Outcome
X_valid, y_valid = data_2_valid.drop(columns=['Outcome', 'Split']), data_2_valid.Outcome
X_test, y_test = data_2_test.drop(columns=['Outcome', 'Split']), data_2_test.Outcome
data_2.Split.value_counts()
# Out:
# test     100
# train     50
# valid     50
# Name: Split, dtype: int64

# %% [markdown]
# ### [2.3] Fit and Evaluate Model
#
# You may notice that the basic ID3 algorithm you developed for the first dataset does not generalize well when applied straight to this problem. Feel free to add extra functionality to it and/or the data preprocessing pipeline that might improve performance on the validation (and ultimately test set).
#
# **Accepted Performance:** Test set accuracy >= 75%

# %%
# %autoreload
import decision_tree as dt  # <-- Your implementation

# Fit model (TO TRAIN SET ONLY)
model_2 = dt.DecisionTree()  # <-- Feel free to add hyperparameters 
model_2.fit(X_train, y_train)

#print(f'Train: {dt.accuracy(y_train, model_2.predict(X_train)) * 100 :.1f}%')
#print(f'Valid: {dt.accuracy(y_valid, model_2.predict(X_valid)) * 100 :.1f}%')
# Out:
# ___________________Node 1 created__________________
# Founder Zodiac information gain: 0.1585
# Founder Experience information gain: 0.0014
# Second Opinion information gain: 0.0001
# Competitive Advantage information gain: 0.0297
# Founder Favourite Color information gain: 0.0913
# Lucurative Market information gain: 0.0143
# ['Founder Zodiac' 'Founder Experience' 'Second Opinion'
#  'Competitive Advantage' 'Founder Favourite Color' 'Lucurative Market']
# {'cancer': [0, 1, 3, 8, 17, 22, 30, 35, 38, 47], 'scorpio': [2, 6, 23, 24, 34, 43], 'taurus': [9, 11, 18, 44, 46, 48], 'pisces': [21, 32, 36, 39, 40, 45], 'aries': [16, 20, 25, 26, 49], 'aquarius': [4, 5, 14, 28], 'gemini': [12, 15, 37], 'sagittarius': [10, 31, 41], 'virgo': [7, 13, 42], 'libra': [29, 33], 'capricorn': [27], 'leo': [19]}
#    Founder Experience Second Opinion Competitive Advantage  \
# 0            moderate       negative                   yes
# 1                high       positive                   yes
# 2                 low       negative                    no
# 3                 low       negative                    no
# 4                 low       positive                   yes
# 5            moderate       positive                    no
# 6                high       negative                    no
# 7            moderate       negative                    no
# 8                high       positive                   yes
# 9            moderate       positive                    no
# 10           moderate       negative                    no
# 11               high       negative                    no
# 12                low       positive                    no
# 13           moderate       negative                    no
# 14               high       negative                    no
# 15           moderate       negative                   yes
# 16           moderate       negative                    no
# 17               high       negative                    no
# 18           moderate       negative                    no
# 19                low       negative                    no
# 20                low       positive                    no
# 21           moderate       positive                    no
# 22                low       negative                    no
# 23           moderate       positive                    no
# 24               high       negative                    no
# 25               high       negative                   yes
# 26           moderate       negative                   yes
# 27               high       positive                   yes
# 28           moderate       positive                    no
# 29           moderate       negative                   yes
# 30                low       negative                   yes
# 31           moderate       negative                    no
# 32                low       negative                    no
# 33                low       negative                   yes
# 34           moderate       negative                    no
# 35                low       negative                   yes
# 36               high       negative                    no
# 37           moderate       positive                    no
# 38           moderate       positive                    no
# 39           moderate       negative                    no
# 40               high       negative                    no
# 41           moderate       negative                   yes
# 42               high       negative                   yes
# 43               high       positive                    no
# 44           moderate       positive                    no
# 45               high       negative                   yes
# 46           moderate       negative                    no
# 47           moderate       positive                    no
# 48           moderate       negative                   yes
# 49           moderate       positive                    no
#
#    Founder Favourite Color Lucurative Market
# 0                    green               yes
# 1                     blue                no
# 2                    green                no
# 3                    black               yes
# 4                      red               yes
# 5                     blue                no
# 6                   yellow               yes
# 7                      red               yes
# 8                    green                no
# 9                      red               yes
# 10                   black                no
# 11                     red                no
# 12                   black                no
# 13                     red                no
# 14                  yellow                no
# 15                   white                no
# 16                    blue                no
# 17                     red                no
# 18                   green                no
# 19                    blue                no
# 20                   white                no
# 21                  yellow                no
# 22                   black                no
# 23                  yellow                no
# 24                   green                no
# 25                    blue                no
# 26                   black                no
# 27                   white                no
# 28                     red                no
# 29                    blue               yes
# 30                   black                no
# 31                   black               yes
# 32                   black                no
# 33                    blue               yes
# 34                  yellow               yes
# 35                    blue               yes
# 36                    blue               yes
# 37                   green                no
# 38                   green                no
# 39                     red               yes
# 40                   white                no
# 41                   white                no
# 42                   green               yes
# 43                   green                no
# 44                   white                no
# 45                     red                no
# 46                     red                no
# 47                  yellow                no
# 48                  yellow                no
# 49                    blue               yes
#
# ___________________Node 2 created__________________
# Founder Experience information gain: 0.4464
# Second Opinion information gain: 0.0074
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.4464
# Lucurative Market information gain: 0.0323
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Founder Favourite Color' 'Lucurative Market']
# {'low': [2, 5, 6, 7], 'high': [1, 3, 4], 'moderate': [0, 8, 9]}
#   Second Opinion Competitive Advantage Founder Favourite Color  \
# 0       negative                   yes                   green
# 1       positive                   yes                    blue
# 2       negative                    no                   black
# 3       positive                   yes                   green
# 4       negative                    no                     red
# 5       negative                    no                   black
# 6       negative                   yes                   black
# 7       negative                   yes                    blue
# 8       positive                    no                   green
# 9       positive                    no                  yellow
#
#   Lucurative Market
# 0               yes
# 1                no
# 2               yes
# 3                no
# 4                no
# 5                no
# 6                no
# 7               yes
# 8                no
# 9                no
#
# ___________________Node 3 created__________________
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Second Opinion' 'Competitive Advantage' 'Founder Favourite Color'
#  'Lucurative Market']
#
# Leaf node value: failure
#
# ___________________Node 4 created__________________
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Second Opinion' 'Competitive Advantage' 'Founder Favourite Color'
#  'Lucurative Market']
#
# Leaf node value: failure
#
# ___________________Node 5 created__________________
# Second Opinion information gain: 0.2516
# Competitive Advantage information gain: 0.2516
# Founder Favourite Color information gain: 0.9183
# Lucurative Market information gain: 0.2516
# ['Second Opinion' 'Competitive Advantage' 'Founder Favourite Color'
#  'Lucurative Market']
# {'green': [0, 1], 'yellow': [2]}
#   Second Opinion Competitive Advantage Lucurative Market
# 0       negative                   yes               yes
# 1       positive                    no                no
# 2       positive                    no                no
#
# ___________________Node 6 created__________________
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Second Opinion' 'Competitive Advantage' 'Lucurative Market']
#
# Leaf node value: success
#
# ___________________Node 7 created__________________
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Second Opinion' 'Competitive Advantage' 'Lucurative Market']
#
# Leaf node value: failure
#
# ___________________Node 8 created__________________
# Founder Experience information gain: 0.1909
# Second Opinion information gain: 0.1092
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.1909
# Lucurative Market information gain: 0.3167
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Founder Favourite Color' 'Lucurative Market']
# {'no': [0, 2, 3, 5], 'yes': [1, 4]}
#   Founder Experience Second Opinion Competitive Advantage  \
# 0                low       negative                    no
# 1               high       negative                    no
# 2           moderate       positive                    no
# 3               high       negative                    no
# 4           moderate       negative                    no
# 5               high       positive                    no
#
#   Founder Favourite Color
# 0                   green
# 1                  yellow
# 2                  yellow
# 3                   green
# 4                  yellow
# 5                   green
#
# ___________________Node 9 created__________________
# Founder Experience information gain: 0.0000
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Founder Favourite Color']
#
# Leaf node value: failure
#
# ___________________Node 10 created__________________
# Founder Experience information gain: 1.0000
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Founder Favourite Color']
# {'high': [0], 'moderate': [1]}
#   Second Opinion Competitive Advantage Founder Favourite Color
# 0       negative                    no                  yellow
# 1       negative                    no                  yellow
#
# ___________________Node 11 created__________________
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# ['Second Opinion' 'Competitive Advantage' 'Founder Favourite Color']
#
# Leaf node value: success
#
# ___________________Node 12 created__________________
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# ['Second Opinion' 'Competitive Advantage' 'Founder Favourite Color']
#
# Leaf node value: failure
#
# ___________________Node 13 created__________________
# Founder Experience information gain: 0.0484
# Second Opinion information gain: 0.1092
# Competitive Advantage information gain: 0.0484
# Founder Favourite Color information gain: 0.1909
# Lucurative Market information gain: 0.0484
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Founder Favourite Color' 'Lucurative Market']
# {'red': [0, 1, 4], 'white': [3], 'yellow': [5], 'green': [2]}
#   Founder Experience Second Opinion Competitive Advantage Lucurative Market
# 0           moderate       positive                    no               yes
# 1               high       negative                    no                no
# 2           moderate       negative                    no                no
# 3           moderate       positive                    no                no
# 4           moderate       negative                    no                no
# 5           moderate       negative                   yes                no
#
# ___________________Node 14 created__________________
# Founder Experience information gain: 0.2516
# Second Opinion information gain: 0.2516
# Competitive Advantage information gain: 0.0000
# Lucurative Market information gain: 0.2516
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Lucurative Market']
# {'moderate': [0, 2], 'high': [1]}
#   Second Opinion Competitive Advantage Lucurative Market
# 0       positive                    no               yes
# 1       negative                    no                no
# 2       negative                    no                no
#
# ___________________Node 15 created__________________
# Second Opinion information gain: 1.0000
# Competitive Advantage information gain: 0.0000
# Lucurative Market information gain: 1.0000
# ['Second Opinion' 'Competitive Advantage' 'Lucurative Market']
# {'positive': [0], 'negative': [1]}
#   Competitive Advantage Lucurative Market
# 0                    no               yes
# 1                    no                no
#
# ___________________Node 16 created__________________
# Competitive Advantage information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Competitive Advantage' 'Lucurative Market']
#
# Leaf node value: failure
#
# ___________________Node 17 created__________________
# Competitive Advantage information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Competitive Advantage' 'Lucurative Market']
#
# Leaf node value: success
#
# ___________________Node 18 created__________________
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Second Opinion' 'Competitive Advantage' 'Lucurative Market']
#
# Leaf node value: failure
#
# ___________________Node 19 created__________________
# Founder Experience information gain: 0.0000
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Lucurative Market']
#
# Leaf node value: failure
#
# ___________________Node 20 created__________________
# Founder Experience information gain: 0.0000
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Lucurative Market']
#
# Leaf node value: failure
#
# ___________________Node 21 created__________________
# Founder Experience information gain: 0.0000
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Lucurative Market']
#
# Leaf node value: failure
#
# ___________________Node 22 created__________________
# Founder Experience information gain: 0.4591
# Second Opinion information gain: 0.1092
# Competitive Advantage information gain: 0.1092
# Founder Favourite Color information gain: 0.9183
# Lucurative Market information gain: 0.0441
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Founder Favourite Color' 'Lucurative Market']
# {'red': [3, 5], 'white': [4], 'blue': [2], 'black': [1], 'yellow': [0]}
#   Founder Experience Second Opinion Competitive Advantage Lucurative Market
# 0           moderate       positive                    no                no
# 1                low       negative                    no                no
# 2               high       negative                    no               yes
# 3           moderate       negative                    no               yes
# 4               high       negative                    no                no
# 5               high       negative                   yes                no
#
# ___________________Node 23 created__________________
# Founder Experience information gain: 0.0000
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Lucurative Market']
#
# Leaf node value: failure
#
# ___________________Node 24 created__________________
# Founder Experience information gain: 0.0000
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Lucurative Market']
#
# Leaf node value: success
#
# ___________________Node 25 created__________________
# Founder Experience information gain: 0.0000
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Lucurative Market']
#
# Leaf node value: success
#
# ___________________Node 26 created__________________
# Founder Experience information gain: 0.0000
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Lucurative Market']
#
# Leaf node value: failure
#
# ___________________Node 27 created__________________
# Founder Experience information gain: 0.0000
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Lucurative Market']
#
# Leaf node value: failure
#
# ___________________Node 28 created__________________
# Founder Experience information gain: 0.4200
# Second Opinion information gain: 0.0200
# Competitive Advantage information gain: 0.0200
# Founder Favourite Color information gain: 0.9710
# Lucurative Market information gain: 0.1710
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Founder Favourite Color' 'Lucurative Market']
# {'blue': [0, 2, 4], 'white': [1], 'black': [3]}
#   Founder Experience Second Opinion Competitive Advantage Lucurative Market
# 0           moderate       negative                    no                no
# 1                low       positive                    no                no
# 2               high       negative                   yes                no
# 3           moderate       negative                   yes                no
# 4           moderate       positive                    no               yes
#
# ___________________Node 29 created__________________
# Founder Experience information gain: 0.0000
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Lucurative Market']
#
# Leaf node value: failure
#
# ___________________Node 30 created__________________
# Founder Experience information gain: 0.0000
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Lucurative Market']
#
# Leaf node value: success
#
# ___________________Node 31 created__________________
# Founder Experience information gain: 0.0000
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Lucurative Market']
#
# Leaf node value: success
#
# ___________________Node 32 created__________________
# Founder Experience information gain: 0.8113
# Second Opinion information gain: 0.1226
# Competitive Advantage information gain: 0.8113
# Founder Favourite Color information gain: 0.3113
# Lucurative Market information gain: 0.8113
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Founder Favourite Color' 'Lucurative Market']
# {'moderate': [1, 3], 'low': [0], 'high': [2]}
#   Second Opinion Competitive Advantage Founder Favourite Color  \
# 0       positive                   yes                     red
# 1       positive                    no                    blue
# 2       negative                    no                  yellow
# 3       positive                    no                     red
#
#   Lucurative Market
# 0               yes
# 1                no
# 2                no
# 3                no
#
# ___________________Node 33 created__________________
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Second Opinion' 'Competitive Advantage' 'Founder Favourite Color'
#  'Lucurative Market']
#
# Leaf node value: failure
#
# ___________________Node 34 created__________________
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Second Opinion' 'Competitive Advantage' 'Founder Favourite Color'
#  'Lucurative Market']
#
# Leaf node value: success
#
# ___________________Node 35 created__________________
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Second Opinion' 'Competitive Advantage' 'Founder Favourite Color'
#  'Lucurative Market']
#
# Leaf node value: failure
#
# ___________________Node 36 created__________________
# Founder Experience information gain: 0.0000
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Founder Favourite Color' 'Lucurative Market']
#
# Leaf node value: success
#
# ___________________Node 37 created__________________
# Founder Experience information gain: 0.0000
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.9183
# Founder Favourite Color information gain: 0.9183
# Lucurative Market information gain: 0.2516
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Founder Favourite Color' 'Lucurative Market']
# {'no': [0, 1], 'yes': [2]}
#   Founder Experience Second Opinion Founder Favourite Color Lucurative Market
# 0           moderate       negative                   black                no
# 1           moderate       negative                   black               yes
# 2           moderate       negative                   white                no
#
# ___________________Node 38 created__________________
# Founder Experience information gain: 0.0000
# Second Opinion information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Founder Favourite Color'
#  'Lucurative Market']
#
# Leaf node value: failure
#
# ___________________Node 39 created__________________
# Founder Experience information gain: 0.0000
# Second Opinion information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Founder Favourite Color'
#  'Lucurative Market']
#
# Leaf node value: success
#
# ___________________Node 40 created__________________
# Founder Experience information gain: 0.9183
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.9183
# Founder Favourite Color information gain: 0.9183
# Lucurative Market information gain: 0.2516
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Founder Favourite Color' 'Lucurative Market']
# {'moderate': [0, 1], 'high': [2]}
#   Second Opinion Competitive Advantage Founder Favourite Color  \
# 0       negative                    no                     red
# 1       negative                    no                     red
# 2       negative                   yes                   green
#
#   Lucurative Market
# 0               yes
# 1                no
# 2               yes
#
# ___________________Node 41 created__________________
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Second Opinion' 'Competitive Advantage' 'Founder Favourite Color'
#  'Lucurative Market']
#
# Leaf node value: failure
#
# ___________________Node 42 created__________________
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Second Opinion' 'Competitive Advantage' 'Founder Favourite Color'
#  'Lucurative Market']
#
# Leaf node value: success
#
# ___________________Node 43 created__________________
# Founder Experience information gain: 1.0000
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Founder Favourite Color' 'Lucurative Market']
# {'low': [1], 'moderate': [0]}
#   Second Opinion Competitive Advantage Founder Favourite Color  \
# 0       negative                   yes                    blue
# 1       negative                   yes                    blue
#
#   Lucurative Market
# 0               yes
# 1               yes
#
# ___________________Node 44 created__________________
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Second Opinion' 'Competitive Advantage' 'Founder Favourite Color'
#  'Lucurative Market']
#
# Leaf node value: failure
#
# ___________________Node 45 created__________________
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Second Opinion' 'Competitive Advantage' 'Founder Favourite Color'
#  'Lucurative Market']
#
# Leaf node value: success
#
# ___________________Node 46 created__________________
# Founder Experience information gain: 0.0000
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Founder Favourite Color' 'Lucurative Market']
#
# Leaf node value: failure
#
# ___________________Node 47 created__________________
# Founder Experience information gain: 0.0000
# Second Opinion information gain: 0.0000
# Competitive Advantage information gain: 0.0000
# Founder Favourite Color information gain: 0.0000
# Lucurative Market information gain: 0.0000
# ['Founder Experience' 'Second Opinion' 'Competitive Advantage'
#  'Founder Favourite Color' 'Lucurative Market']
#
# Leaf node value: failure

# %% [markdown]
# ## [3] Further steps (optional)
#
# If you're done with the assignment but want to some more challenges; consider the following:
#
# - Make a Decision Tree learner that can handle numerical attributes
# - Make a Decision Tree learner that can handle numerical targets (regresion tree)
# - Try implementing [Random Forest](https://en.wikipedia.org/wiki/Random_forest) on top of your Decision Tree algorithm
#
# If you need more data for experimenting, UC Irvine hosts a [large repository](https://archive.ics.uci.edu/ml/datasets.php) of machine learning datasets.
